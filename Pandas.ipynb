# %%
import pandas as pd

# %%
df =pd.read_csv("tested.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ### Creating DataFrame

# %%
data ={'name':["JON","ROY"],'age':[25,23],'ID':[1,2]}

# %%
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#   name  age  ID
# 0  JON   25   1
# 1  ROY   23   2

# %%
data2 = {"Address":["Pune","Mumbai"],'ID':[1,2]}

# %%
df2 = pd.DataFrame(data2)

# %%
df2
# Out:
#   Address  ID
# 0    Pune   1
# 1  Mumbai   2

# %% [markdown]
# ### selecting Column

# %%
ages = df['Age']

# %% [markdown]
# ###  Filtering Row

# %%
f_rows = df[df['Age']>26]

# %%
f_rows.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %% [markdown]
# ###  Adding a Column

# %%
df["Country"]=["India","USA","Russia"] #ValueError: Length of values (3) does not match length of index (418)

# %% [markdown]
# ### Drop Column

# %%
drop_df= df.drop('Cabin',axis = 1)

# %%
drop_df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# ...

# %% [markdown]
# df.isnull().sum()

# %% [markdown]
# ###  Handling Missing Data/

# %%
df['Age']=df['Age'].fillna(0)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ### Group By

# %%
groupedby_df = df.groupby('Sex')['Age'].mean()

# %%
groupedby_df.head()
# Out:
# Sex
# female    25.293355
# male      23.330489
# Name: Age, dtype: float64

# %% [markdown]
# ###  Merging DataFrames

# %%
merged_df= pd.merge(df1 ,df2,on='ID')

# %%
merged_df
# Out:
#   name  age  ID Address
# 0  JON   25   1    Pune

# %% [markdown]
# ### Pivot table

# %%
pivot_df = df.pivot_table(values='Age',index='Sex',columns='Fare',aggfunc='sum')

# %% [markdown]
# ### joined dataframe

# %%
joined_df = df1.join(df2,on='ID', how ='inner')

# %% [markdown]
# ### Applying Function

# %%
df['Ages_In_Days']=df["Age"].apply(lambda x : x*365)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ### Sorting Data

# %%
sorted_df = df.sort_values(by='Age',ascending = True)

# %%
sorted_df
# Out:
#      PassengerId  Survived  Pclass  \
# 417         1309         0       3
# 133         1025         0       3
# 382         1274         1       3
# 227         1119         1       3
# 225         1117         1       3
# ..           ...       ...     ...
# 305         1197         1       1
# 179         1071         1       1
# 236         1128         0       1
# 81           973         0       1
# 96           988         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 417                           Peter, Master. Michael J    male   0.0      1
# 133                              Thomas, Mr. Charles P    male   0.0      1
# 382                         Risien, Mrs. Samuel (Emma)  female   0.0      0
# 227                             McNeill, Miss. Bridget  female   0.0      0
# 225   Moubarek, Mrs. George (Omine Amenia" Alexander)"  female   0.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ###  DataFrame Iteration

# %%
for index,row in df.iterrows():
    print(row['Name'],row['Age'])
# Out:
# Kelly, Mr. James 34.5
# Wilkes, Mrs. James (Ellen Needs) 47.0
# Myles, Mr. Thomas Francis 62.0
# Wirz, Mr. Albert 27.0
# Hirvonen, Mrs. Alexander (Helga E Lindqvist) 22.0
# Svensson, Mr. Johan Cervin 14.0
# Connolly, Miss. Kate 30.0
# Caldwell, Mr. Albert Francis 26.0
# Abrahim, Mrs. Joseph (Sophie Halaut Easu) 18.0
# Davies, Mr. John Samuel 21.0
# Ilieff, Mr. Ylio 0.0
# Jones, Mr. Charles Cresson 46.0
# Snyder, Mrs. John Pillsbury (Nelle Stevenson) 23.0
# Howard, Mr. Benjamin 63.0
# Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood) 47.0
# del Carlo, Mrs. Sebastiano (Argenia Genovesi) 24.0
# Keane, Mr. Daniel 35.0
# Assaf, Mr. Gerios 21.0
# Ilmakangas, Miss. Ida Livija 27.0
# Assaf Khalil, Mrs. Mariana (Miriam")" 45.0
# Rothschild, Mr. Martin 55.0
# Olsen, Master. Artur Karl 9.0
# Flegenheim, Mrs. Alfred (Antoinette) 0.0
# Williams, Mr. Richard Norris II 21.0
# Ryerson, Mrs. Arthur Larned (Emily Maria Borie) 48.0
# Robins, Mr. Alexander A 50.0
# ...

# %% [markdown]
# ###  Concatenating DataFrame

# %%
concatenated_df=pd.concat([df1,df2],axis=0)

# %%
concatenated_df
# Out:
#   name   age  ID Address
# 0  JON  25.0   1     NaN
# 1  ROY  23.0   2     NaN
# 0  NaN   NaN   1    Pune
# 1  NaN   NaN   2  Mumbai

# %% [markdown]
# ### Removing Duplicate

# %%
dup_df =df.drop_duplicates(['Age'])

# %%
dup_df.head(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 6            898         1       3
# 7            899         0       2
# 8            900         1       3
# 9            901         0       3
# 10           902         0       3
# 11           903         0       1
# 12           904         1       1
# 13           905         0       2
# 15           907         1       2
# 16           908         0       2
# 19           911         1       3
# 20           912         0       1
# 21           913         0       3
# 24           916         1       1
# 25           917         0       3
# 27           919         0       3
# 28           920         0       1
# 32           924         1       3
# 35           927         0       3
# ...

# %% [markdown]
# ### Transposing DF

# %%
transposed_df = df.T

# %%
transposed_df
# Out:
#                            0                                 1    \
# PassengerId                892                               893
# Survived                     0                                 1
# Pclass                       3                                 3
# Name          Kelly, Mr. James  Wilkes, Mrs. James (Ellen Needs)
# Sex                       male                            female
# Age                       34.5                              47.0
# SibSp                        0                                 1
# Parch                        0                                 0
# Ticket                  330911                            363272
# Fare                    7.8292                               7.0
# Cabin                      NaN                               NaN
# Embarked                     Q                                 S
# Ages_In_Days           12592.5                           17155.0
#
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# ###  Rename Columns

# %%
rename_df = df.rename(columns={'PassengerId':'Pass_ID'})

# %%
rename_df
# Out:
#      Pass_ID  Survived  Pclass                                          Name  \
# 0        892         0       3                              Kelly, Mr. James
# 1        893         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2        894         0       2                     Myles, Mr. Thomas Francis
# 3        895         0       3                              Wirz, Mr. Albert
# 4        896         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..       ...       ...     ...                                           ...
# 413     1305         0       3                            Spector, Mr. Woolf
# 414     1306         1       1                  Oliva y Ocana, Dona. Fermina
# 415     1307         0       3                  Saether, Mr. Simon Sivertsen
# 416     1308         0       3                           Ware, Mr. Frederick
# 417     1309         0       3                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# ###  Handling NaN Values

# %%
nan_value = df.isna().sum()

# %%
nan_value
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ###  Filling NaN with Mean

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### Dropping Rows with NaN

# %%
drop_df = df.dropna()

# %%
drop_df.head(100)
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
condi_drop = df[df['Age']>50]

# %%
condi_drop
# Out:
#      PassengerId  Survived  Pclass  \
# 2            894         0       2
# 13           905         0       2
# 20           912         0       1
# 48           940         1       1
# 69           961         1       1
# 77           969         1       1
# 81           973         0       1
# 96           988         1       1
# 114         1006         1       1
# 131         1023         0       1
# 142         1034         0       1
# 152         1044         0       3
# 177         1069         0       1
# 179         1071         1       1
# 193         1085         0       2
# 213         1105         1       2
# 217         1109         0       1
# 224         1116         1       1
# 236         1128         0       1
# 240         1132         1       1
# 293         1185         0       1
# 305         1197         1       1
# 308         1200         0       1
# 314         1206         1       1
# 316         1208         0       1
# ...

# %% [markdown]
# ### reseting  index

# %%
reset_df=drop_df.reset_index(drop=True)

# %%
reset_df
# Out:
#     PassengerId  Survived  Pclass  \
# 0           904         1       1
# 1           906         1       1
# 2           916         1       1
# 3           918         1       1
# 4           920         0       1
# ..          ...       ...     ...
# 86         1296         0       1
# 87         1297         0       2
# 88         1299         0       1
# 89         1303         1       1
# 90         1306         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 1   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 2     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 3                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 4                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                ...     ...   ...    ...
# ...

# %% [markdown]
# ### unique Values

# %%
unique_df=df['Age'].unique()

# %%
unique_df
# Out:
# array([34.5       , 47.        , 62.        , 27.        , 22.        ,
#        14.        , 30.        , 26.        , 18.        , 21.        ,
#        30.27259036, 46.        , 23.        , 63.        , 24.        ,
#        35.        , 45.        , 55.        ,  9.        , 48.        ,
#        50.        , 22.5       , 41.        , 33.        , 18.5       ,
#        25.        , 39.        , 60.        , 36.        , 20.        ,
#        28.        , 10.        , 17.        , 32.        , 13.        ,
#        31.        , 29.        , 28.5       , 32.5       ,  6.        ,
#        67.        , 49.        ,  2.        , 76.        , 43.        ,
#        16.        ,  1.        , 12.        , 42.        , 53.        ,
#        26.5       , 40.        , 61.        , 60.5       ,  7.        ,
#        15.        , 54.        , 64.        , 37.        , 34.        ,
#        11.5       ,  8.        ,  0.33      , 38.        , 57.        ,
# ...

# %% [markdown]
# ### Value Counts

# %%
age_counts = df['Age'].value_counts()

# %%
age_counts
# Out:
# Age
# 30.27259    86
# 24.00000    17
# 21.00000    17
# 22.00000    16
# 30.00000    15
#             ..
# 76.00000     1
# 28.50000     1
# 22.50000     1
# 62.00000     1
# 38.50000     1
# Name: count, Length: 80, dtype: int64

# %% [markdown]
# ### Value Counts

# %%
df['Name']=df['Name'].str.upper()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                KELLY, MR. JAMES    male  34.50000      0
# 1                WILKES, MRS. JAMES (ELLEN NEEDS)  female  47.00000      1
# 2                       MYLES, MR. THOMAS FRANCIS    male  62.00000      0
# 3                                WIRZ, MR. ALBERT    male  27.00000      0
# 4    HIRVONEN, MRS. ALEXANDER (HELGA E LINDQVIST)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %% [markdown]
# ### Cumulative Operations

# %%
df['CumulativeSum']=df['Fare'].cumsum()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                KELLY, MR. JAMES    male  34.50000      0
# 1                WILKES, MRS. JAMES (ELLEN NEEDS)  female  47.00000      1
# 2                       MYLES, MR. THOMAS FRANCIS    male  62.00000      0
# 3                                WIRZ, MR. ALBERT    male  27.00000      0
# 4    HIRVONEN, MRS. ALEXANDER (HELGA E LINDQVIST)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %% [markdown]
# ### Correlation MAtrix

# %%
correlatiin = df.corr()

# %% [markdown]
# ###  Conditional Replacement

# %%
df['Status']=df['Age'].apply(lambda x: "Adult" if x>=18 else "Minor")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                KELLY, MR. JAMES    male  34.50000      0
# 1                WILKES, MRS. JAMES (ELLEN NEEDS)  female  47.00000      1
# 2                       MYLES, MR. THOMAS FRANCIS    male  62.00000      0
# 3                                WIRZ, MR. ALBERT    male  27.00000      0
# 4    HIRVONEN, MRS. ALEXANDER (HELGA E LINDQVIST)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
status_counts = df['Status'].value_counts()

# %%
status_counts
# Out:
# Status
# Adult    377
# Minor     41
# Name: count, dtype: int64

# %% [markdown]
# ###  DataFrame Slicing

# %%
slice_df = df.loc[0:50,['Name','Sex','Age']]

# %%
slice_df
# Out:
#                                                  Name     Sex       Age
# 0                                    KELLY, MR. JAMES    male  34.50000
# 1                    WILKES, MRS. JAMES (ELLEN NEEDS)  female  47.00000
# 2                           MYLES, MR. THOMAS FRANCIS    male  62.00000
# 3                                    WIRZ, MR. ALBERT    male  27.00000
# 4        HIRVONEN, MRS. ALEXANDER (HELGA E LINDQVIST)  female  22.00000
# 5                          SVENSSON, MR. JOHAN CERVIN    male  14.00000
# 6                                CONNOLLY, MISS. KATE  female  30.00000
# 7                        CALDWELL, MR. ALBERT FRANCIS    male  26.00000
# 8           ABRAHIM, MRS. JOSEPH (SOPHIE HALAUT EASU)  female  18.00000
# 9                             DAVIES, MR. JOHN SAMUEL    male  21.00000
# 10                                   ILIEFF, MR. YLIO    male  30.27259
# 11                         JONES, MR. CHARLES CRESSON    male  46.00000
# ...

# %% [markdown]
# ### Cross Tabulation

# %%
cross_df = pd.crosstab(df['Sex'],df['Fare'])

# %%
cross_df
# Out:
# Fare    0.0000    3.1708    6.4375    6.4958    6.9500    7.0000    7.0500    \
# Sex
# female         0         0         0         0         1         1         0
# male           2         1         2         1         0         1         2
#
# Fare    7.2250    7.2292    7.2500    ...  151.5500  164.8667  211.3375  \
# Sex                                   ...
# female         1         2         0  ...         1         1         1
# male           8         7         5  ...         1         1         0
#
# Fare    211.5000  221.7792  227.5250  247.5208  262.3750  263.0000  512.3292
# Sex
# female         2         2         0         1         3         2         1
# male           2         1         1         0         2         0         0
#
# [2 rows x 169 columns]

# %% [markdown]
# ### Stacking and Unstacking

# %%
stacked_df = df.stack()

# %%
stacked_df.head(10)
# Out:
# 0  PassengerId                 892
#    Survived                      0
#    Pclass                        3
#    Name           Kelly, Mr. James
#    Sex                        male
#    Age                        34.5
#    SibSp                         0
#    Parch                         0
#    Ticket                   330911
#    Fare                     7.8292
# dtype: object

# %%
unstacked_df =stacked_df.unstack()

# %%
# Out:
#     PassengerId Survived Pclass                                          Name  \
# 0           892        0      3                              Kelly, Mr. James
# 1           893        1      3              Wilkes, Mrs. James (Ellen Needs)
# 2           894        0      2                     Myles, Mr. Thomas Francis
# 3           895        0      3                              Wirz, Mr. Albert
# 4           896        1      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..          ...      ...    ...                                           ...
# 413        1305        0      3                            Spector, Mr. Woolf
# 414        1306        1      1                  Oliva y Ocana, Dona. Fermina
# 415        1307        0      3                  Saether, Mr. Simon Sivertsen
# 416        1308        0      3                           Ware, Mr. Frederick
# 417        1309        0      3                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# ### Querying DataFrame

# %%
fillterd_df =df.query('Age> 25 & Sex=="male"')

# %%
fillterd_df
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# 11           903         0       1    Jones, Mr. Charles Cresson  male  46.0
# ..           ...       ...     ...                           ...   ...   ...
# 399         1291         0       3      Conlon, Mr. Thomas Henry  male  31.0
# 401         1293         0       2               Gale, Mr. Harry  male  38.0
# 404         1296         0       1  Frauenthal, Mr. Isaac Gerald  male  43.0
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
#
# ...

# %% [markdown]
# ### Expanding mean

# %%
df['Expanding Mean']=df['Age'].expanding().mean()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ## THANK YOU
